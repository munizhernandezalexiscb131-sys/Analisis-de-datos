# %% [markdown]
# <a href="https://colab.research.google.com/github/munizhernandezalexiscb131-sys/Analisis-de-datos/blob/main/PY5_Alexis_Mu%C3%B1iz_Hernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
reviews_harvard = pd.read_csv("datasets/harvard_reviews.csv", index_col = 0)
pd.set_option("display.max_rows", 5)
reviews_harvard
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review              0
# 2023-12-12T00:38:26-05:00            Desktop       4  review              0
# ...                                      ...     ...     ...            ...
# 2010-06-03T07:37:36-04:00            Desktop       5  review              2
# 2009-09-27T16:39:18-04:00            Desktop       5  review              1
#
#                                                                        title  \
# published_date
# 2023-12-28T08:02:14-05:00                 Best classes and good environment
# 2023-12-12T00:38:26-05:00                                 Harvard University
# ...                                                                      ...
# 2010-06-03T07:37:36-04:00  Tolle Universität, definitiv einen Abstecher wert
# 2009-09-27T16:39:18-04:00                                            一度は行くべき
#
# ...

# %%
reviews_harvard.shape
# Out:
# (3184, 6)

# %%
reviews_harvard.iloc[0]
# Out:
# published_platform                                               Mobile
# rating                                                                5
#                                             ...
# title                                Best classes and good environment
# text                  Good thanks for everything good work group 👍 h...
# Name: 2023-12-28T08:02:14-05:00, Length: 6, dtype: object

# %%
reviews_harvard.iloc[[0]]
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review              0
#
#                                                         title  \
# published_date
# 2023-12-28T08:02:14-05:00  Best classes and good environment
#
#                                                                         text
# published_date
# 2023-12-28T08:02:14-05:00  Good thanks for everything good work group 👍 h...

# %%
reviews_harvard.iloc[:,0]
# Out:
# published_date
# 2023-12-28T08:02:14-05:00     Mobile
# 2023-12-12T00:38:26-05:00    Desktop
#                               ...
# 2010-06-03T07:37:36-04:00    Desktop
# 2009-09-27T16:39:18-04:00    Desktop
# Name: published_platform, Length: 3184, dtype: object

# %%
reviews_harvard.iloc[:3,:3]
# Out:
#                           published_platform  rating    type
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review
# 2023-12-12T00:38:26-05:00            Desktop       4  review
# 2023-12-10T08:21:35-05:00             Mobile       3  review

# %%
reviews_harvard.iloc[[0,2], [1,3]]
# Out:
#                            rating  helpful_votes
# published_date
# 2023-12-28T08:02:14-05:00       5              0
# 2023-12-10T08:21:35-05:00       3              0

# %%
reviews_harvard.iloc[-5:]
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2010-10-29T05:47:57-04:00            Desktop       3  review              0
# 2010-08-23T06:08:51-04:00            Desktop       3  review              0
# 2010-08-23T00:06:41-04:00            Desktop       5  review              0
# 2010-06-03T07:37:36-04:00            Desktop       5  review              2
# 2009-09-27T16:39:18-04:00            Desktop       5  review              1
#
#                                                                        title  \
# published_date
# 2010-10-29T05:47:57-04:00               amerikanischer campus fuer touristen
# 2010-08-23T06:08:51-04:00                               Weniger als erwartet
# 2010-08-23T00:06:41-04:00                              bellissima università
# 2010-06-03T07:37:36-04:00  Tolle Universität, definitiv einen Abstecher wert
# 2009-09-27T16:39:18-04:00                                            一度は行くべき
#
# ...

# %%
reviews_harvard.loc[reviews_harvard.rating == '4']
# Out:
# Empty DataFrame
# Columns: [published_platform, rating, type, helpful_votes, title, text]
# Index: []

# %% [markdown]
# Carlos es un investigador que estudia la percepción de los estudiantes sobre los cursos en línea de Harvard. Para ello utiliza el archivo **harvard_reviews.csv**, donde se registran las reseñas con su calificación, tipo de contenido, texto, votos útiles y plataforma de publicación. Al analizar los datos, descubre que los cursos con mejor valoración suelen incluir explicaciones claras y ejemplos prácticos, mientras que los peor evaluados reciben críticas por falta de interacción. Con esta información, Carlos elabora un informe que ayuda a los instructores a mejorar sus métodos de enseñanza y a la universidad a fortalecer la calidad de sus programas digitales.
